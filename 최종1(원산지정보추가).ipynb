# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 한식[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[2]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 40:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.6)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass
    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)

# 각 가게 링크에 접속 후 파싱
# 가게주소
store_address=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

for num, _ in enumerate(store_href, start=1):    
    try:
        driver.find_element_by_xpath(f'//*[@id="restaurants"]/div/a[{num}]').send_keys(Keys.ENTER)
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
    except:
        print(f'//*[@id="restaurants"]/div/a[{num}] 번 오류')
        pass
    # 주소뽑기
    try:
        store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p')[1]
        store_address_str = store_address.get_text("서울", strip=True)
        store_address_detail = store_address_str[6:]
        store_address.append(store_address_detail)
    except:
        pass
    print(store_address_detail)
    print('주소 뽑기 성공')
    print('=========================================')
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')
    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#         store_info_list.append(store_info_str)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
    # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        store_origin_infos.append(store_origin_info)
        print(store_origin_info)
        print('가게 원산지 뽑기 성공')
        print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
    store_moneyss.append(store_moneys)
    print(store_moneyss)
    print('최소 금액 성공')
    print('=========================================')
    
    store_details_menu = soup.select('.left-section > .menu-category > .row-menu')
    for menu in store_details_menu:
        # 음식 메뉴
        store_menu = menu.select_one(".pull-left").find_next('strong').get_text(strip=True)
        store_menus.append(store_menu)
        print(store_menu)
        print('음식 메뉴 성공')
        print('=========================================')
        
        # 음식 정보
        store_description = menu.select_one('.pull-left > span').get_text("", strip=True)
        store_descriptions.append(store_description)
        print(store_description)
        print('음식 정보 성공')
        print('=========================================')
        
        # 음식 가격
        store_price = menu.select_one("span.calculate-price").get_text(strip=True)
        a = re.split(',', store_price)
        aprice = ''
        for i in a:
            aprice += i
        price = int(aprice)
        store_prices.append(price)
        print(price)
        print('음식 가격 성공')
        print('=========================================')
      
    
    print('================== 가게 하나 끝 ==================')
#     print(store_menu, price)
#     print(store_description)
    
#     print(store_address)
#     print(store_info_list)
#     print(store_moneyss)
#     print(store_menus)
#     print(store_prices)
#     print(store_descriptions)
    
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    driver.back()
    driver.implicitly_wait(8)
# Out:
# /home/hanyonghee/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead
# 서울 강남구 역삼동 669-6 전원빌딩 지하 1층
# 주소 뽑기 성공
# =========================================
#
# [CHEFLY] 당신만을 위한 셰프의 한끼
#
# 대한민국 대표 셰프들의 요리를
# 온라인주문+즉시조리+즉시배송으로
# 원하는 시간과 장소에서 편하게 즐기실 수 있는
# 신개념 온라인 음식배달 서비스입니다
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 가게 원산지 뽑기 성공
# =========================================
# [메인메뉴_완조리]
# 가게 원산지 뽑기 성공
# =========================================
#
# 가게 원산지 뽑기 성공
# =========================================
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리 :새우(베트남산), 채소류(국내산, 중국산), 레드커리페이스트(태국산), 휘핑크림(국내산)
# 가게 원산지 뽑기 성공
# =========================================
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또 : 닭다리살(브라질산), 치킨파우더(대만산), 잡곡(국내산), 고르곤졸라(이탈리아산)
# 가게 원산지 뽑기 성공
# =========================================
# 매콤한 낙지 콩나물비빔밥 : 쌀(국내산), 낙지(중국산), 채소류(국내산)
# 가게 원산지 뽑기 성공
# =========================================
# 그라나파다노를 곁들인 닭다리살 김치볶음밥 :김치(국내산), 쌀(국내산), 계란(국내산), 채소류(국내산), 정육(브라질산), 그라나파다노(이탈리아산), 트러플오일(이탈리아산), 굴소스(홍콩산), 두반장(중국산)
# 가게 원산지 뽑기 성공
# =========================================
# 소불고기 궁중 비빔밥 '골동반' :소고기(호주산), 계란(국내산), 시금치(국내산), 튀각(국내산), 쌀(국내산), 미역(국내산), 고사리(중국산), 당근(중국산), 청포묵(중국산), 숙주(중국산), 은행(중국산)
# 가게 원산지 뽑기 성공
# =========================================
# 국내산 생등심 돈가츠 덮밥 '가츠동' :돼지등심(국내산), 계란(국내산), 쌀(국내산), 채소류(국내산), 간장(일본산), 단무지(중국산), 락교(중국산)
# 가게 원산지 뽑기 성공
# =========================================
#
# 가게 원산지 뽑기 성공
# =========================================
# [8000]
# 최소 금액 성공
# =========================================
# 고소하고 상큼한  흑임자 알감자 샐러드
# 음식 메뉴 성공
# =========================================
# 버터에 노릇노릇하게 구운 알감자에 볶음 흑임자 드레싱의 고소함과 레몬 드레싱의 상큼함을 가미했습니다.포슬포슬한 알감자와 상큼한 토마토, 아삭한 브로콜리까지!지금까지 없던 맛과 멋, 건강까지 고려한 셰플리의 야심작입니다. 소소하지만 확실한 행복을 즐겨보세요~
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 종가집 김치 50g
# 음식 메뉴 성공
# =========================================
# 전통한식에 모던을 담다 '종가집' X 당신만을 위한 셰프의 한끼 '셰플리'종가집에서 관리하는 최상급 국내산 농산물을 100% 사용하였으며, 종가집 특유의 신선발효비법(유산균)으로 풍부한 감칠맛이 일품인 김치입니다.
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 오렌지 필로 풍미를 더한 수제 티라미수
# 음식 메뉴 성공
# =========================================
# 기분전환이 필요한 당신을 위한 셰플리만의 프리미엄 디저트.아몬드 리큐르 향 에스프레소로 적신 핑거쿠키, 마스카포네 치즈와  다크커버춰 초콜릿 위에 오렌지 필로 풍미를 더한 티라미수*원산지 : 다크커버춰(프랑스산), 마스카포네(이탈리아산), 사보이아르디(이탈리아산), 계란(국내산), 생크림(국내산), 오렌지(미국산), 리큐르(네덜란드산)
# 음식 정보 성공
# =========================================
# 4500
# 음식 가격 성공
# =========================================
# 반숙계란 니스와즈 샐러드
# 음식 메뉴 성공
# =========================================
# 올리브, 그린빈, 알감자, 참치 등 각종 건강 재료에 와인비니거로 제조한 프렌치 드레싱과 반숙계란을 곁들인 프랑스 니스 풍의 지중해식 샐러드*원산지 : 그린빈(중국산), 감자(국내산), 블랙올리브(스페인산), 계란(국내산), 참치(우너양산), 로메인(국내산), 방울토마토(국내산)
# 음식 정보 성공
# =========================================
# 5000
# 음식 가격 성공
# =========================================
# 고소한 명란마요 밥
# 음식 메뉴 성공
# =========================================
# 밥도둑의 대명사 명란과 고소한 참기름, 김가루로 입맛을 살릴 셰플리 첫 한식 사이드 메뉴*원산지 : 쌀 (국내산), 명란 (러시아산)
# 음식 정보 성공
# =========================================
# 2700
# 음식 가격 성공
# =========================================
# 명란마요소스 치킨 가라아게(5조각)
# 음식 메뉴 성공
# =========================================
# 겉은 바삭하고 속은 촉촉하게 튀겨낸 닭다리살을 명란과 마요네즈 등으로 셰프가 직접 배합하여 만든 특제 소스에 찍어먹는 일본 대표 가정식*원산지 :정육(태국산), 명란(러시아산)
# 음식 정보 성공
# =========================================
# 5000
# 음식 가격 성공
# =========================================
# 트러플향 감자튀김
# 음식 메뉴 성공
# =========================================
# 세계 3대 진미 중 하나인 트러플의 향을 느끼실 수 있는 감자튀김고소하고 짭조름한 맛은 맥주와 함께 드실 때에 더 맛있습니다(케첩 없이도 맛있게 드실 수 있습니다)*원산지 : 감자튀김(미국산), 트러플오일(이탈리아산)
# 음식 정보 성공
# =========================================
# 4500
# 음식 가격 성공
# =========================================
# 뉴욕식 버팔로윙(5조각)
# 음식 메뉴 성공
# =========================================
# 셰플리가 직접 배합한 뉴욕식 바베큐소스를 하나하나 정성껏 발라 구운 뒤 파슬리와 아몬드로 마무리하여 고소하고 매콤달콤한 맛이 특징인 오리지널 치킨윙*원산지: 치킨윙(태국산)
# 음식 정보 성공
# =========================================
# 5000
# 음식 가격 성공
# =========================================
# 흰 밥 추가
# 음식 메뉴 성공
# =========================================
# *원산지 : 쌀(국내산)
# 음식 정보 성공
# =========================================
# 1500
# 음식 가격 성공
# =========================================
# 피나콜라다 코코넛 시럽을 곁들인 상큼한 파인애플
# 음식 메뉴 성공
# =========================================
# 상큼한 파인애플 위에 뿌려진 부드러운 코코넛 시럽의 환상적인 조화!떠나는 여름이 아쉬운 당신을 위해 준비한 동남아 스타일의 디저트입니다.과즙 가득 새콤달콤한 파인애플 위에 풍미 가득한 피나콜라다 코코넛 시럽을 곁들이면 이 곳이 바로 휴양지 해변가!
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 마이빈스 더치커피
# 음식 메뉴 성공
# =========================================
# 콜롬비아/브라질/과테말라를 블랜딩하여 제조일자 표기로 믿음을 더한 더치커피! 물과 더치커피의 1:3 황금비율로 시원한 얼음 또는 뜨거운 물과  함께 드실 수 있습니다. (기본 컵 제공됩니다)
# 음식 정보 성공
# =========================================
# 1500
# 음식 가격 성공
# =========================================
# 마르티넬리 스파클링 애플주스
# 음식 메뉴 성공
# =========================================
# 최고품질의 사과로만 만든 100% 천연 사과탄산주스물, 향료, 설탕을 넣지 않아 사과 본연의 깔끔한 맛을 느낄 수 있습니다
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 산펠레그리노 폼펠모 자몽
# 음식 메뉴 성공
# =========================================
# 산펠레그리노 탄산수에 자몽향과 맛을 가미한 제품자몽의 달콤 쌉싸름한 맛은 음료의 향을 한층 더 끌어올려 주고, 달콤한 맛이 신맛을 부드럽게 감싸주는 기분좋은 끝맛을 느껴보세요고품질의 자몽주스와 신선한 귤향을 첨가하여 마시는 순간 상쾌함과 함께 갈증이 해소됩니다
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 오미베리 베리티
# 음식 메뉴 성공
# =========================================
# 오미자열매 3송이가 그대로~ 천연원료만을 사용하였으며, 항산화 물질이 피로회복에 효과가 있어 무더운 여름 건강과 맛 둘 다 잡아보세요
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 산펠레그리노 아란시아타 로싸
# 음식 메뉴 성공
# =========================================
# 산펠레그리노 천연 탄산수에 시칠리아산 레드 오렌지 원액을 함유하고 있는 부드러운 레드오렌지 탄산음료잘 익은 블러드 오렌지의 강렬한 향과 부드럽고 우아한 단맛을 느껴보세요
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 코카콜라
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1500
# 음식 가격 성공
# =========================================
# 코카콜라 제로
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1500
# 음식 가격 성공
# =========================================
# 스프라이트
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1500
# 음식 가격 성공
# =========================================
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]SNS를 뜨겁게 달군 자꾸만 생각나는 중독의 그 맛!특제 간장에서 잘 숙성시킨 새우와 연어를 고슬고슬하게 갓 지은 밥 위에 얹어 감칠맛나게 푸짐한 한끼를 구성했습니다.고소한 버터와 함께 계란 노른자를 톡 터뜨려 따뜻한 밥을 코팅해주고, 부드러운 연어와 탱탱한 새우를 한 숟가락 가득 떠먹어보세요.비린맛은 ZERO! 입 안에서 톡톡터지는 날치알의 재밌는 식감과 상큼하게 채 썬 양파와 초생강, 무순으로 뒷맛까지 담백하고 깔끔하게~첫 숟가락부터 반하게 될 셰플리표 연어새우장 덮밥.행복한 비명이 절로 나오는 알차고 야무진 한 끼를 즐겨보세요.CHEF'S TIP전자레인지에 데우지 않으셔도 맛있게 드실 수 있습니다.다양한 토핑을 밥과 함께 잘 비벼 드세요.달걀 노른자는 기호에 맞게 즐겨보세요.
# 음식 정보 성공
# =========================================
# 12000
# 음식 가격 성공
# =========================================
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]신선한 로메인과 루꼴라가 듬뿍! 누구나 좋아할만한 시저샐러드에 특제 허니갈릭 소스를 발라 구운 닭가슴살과, 콜비잭 치즈, 블랙올리브, 적양파, 베이컨, 삶은 달걀, 방울토마토를 올려 다채로운 비주얼만큼 푸짐하게 구성했습니다.구운 피타브래드에 신선한 채소와 각종 고명을 취향껏 함께 올려 싸먹어보세요. 셰플리만의 홈메이드 시저 드레싱에 청양고추로 약간의 매콤함을 더해 뒷맛까지 깔끔한 한끼를 즐기실 수 있습니다.CHEF'S TIP피타브래드를 부드럽게 즐기시려면 전자레인지에 30초 데워주세요.드레싱은 기호에 맞게 샐러드와 충분히 섞어 드세요.다양한 토핑과 샐러드를 함께 드시면 더 맛있습니다.
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# 특제간장으로 맛을 살린 여수 새꼬막비빔밥
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]2017 미슐랭 가이드 서울편에 등재된 모던한식 레스토랑 '민스키친(MIN'S KITCHEN)'의 김민지 오너셰프의 노하우를 바탕으로 셰플리 키친팀이 구현한 꼬막비빔밥제철을 맞이한 신선한 여수 새꼬막을 사용하여 쫄깃하고 탱탱한 식감이 일품인 비빔밥궁채, 아삭고추, 미나리, 쪽파, 부추 등 파릇파릇한 색감의 5가지 초록 채소와 아삭한 콩나물의 환상적 조화!매콤하면서도 감칠맛 나는 특제 숙성 간장으로 양념하여 비린맛 없이 여수 꼬막 특유의 맛과 풍미를 즐기실 수 있습니다.올 겨울, 남해 바다가 눈 앞에 펼쳐지는 셰플리표 꼬막 한 상을 느껴보세요. 혼밥, 혼술로도 제격입니다.-인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다.CHEF'S TIP전자레인지에 데우지 않으셔도 맛있게 드실 수 있습니다.다양한 채소를 밥과 함께 잘 비벼드세요.비빔밥과 미역국을 곁들여 먹으면 더욱 맛있습니다.
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]셰플리 인기메뉴 재출시!향신료 풍미 가득, 입맛 당기는 동남아풍 부드러운 레드커리에 스파이시하게 구운 케이준 쉬림프를 올린 인기 앵콜메뉴컬리플라워, 연근, 그린빈, 단호박, 느타리버섯 등 5가지의 다채로운 야채를 오븐에 구워 영양소 파괴는 최소화하고, 부드러운 식감과 푸짐함은 극대화하였습니다.지나간 여름 휴가가 떠오르는 동남아의 향미와, 다가올 가을이 기대되는 맛과 멋이 공존하는 셰플리표 레드커리를 즐겨보세요!CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.커리소스를 고루 부어서 잘 비벼드세요.사이드로 드린 할라피뇨는 취향에 맞게 즐겨보세요.
# 음식 정보 성공
# =========================================
# 12000
# 음식 가격 성공
# =========================================
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]서래마을의 유명 레스토랑 '도우룸 바이 스와니예(Doughroom by Soigne)' 윤대현 헤드셰프의 레시피로부터 영감을 받아 셰플리 키친팀만의 방식으로 재해석하여 탄생한 요리현미와 보리를 믹스하여 밥알의 탱글함을 살린 고르곤졸라 크림리조또에 청양고추를 넣어 느끼함은 잡고, 특별하게 구운 황금팽이로 풍미는 더하였습니다장시간 마리네이드하여 허브향을 입힌 부드러운 오븐구이 닭다리살과 신선한 이태리 파슬리를 얹어 마무리한 정성 가득한 리조또입니다CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.황금팽이버섯은 리조또와 함께 섞어 드시면 더욱 맛있습니다.사이드로 드린 할라피뇨는 취향에 맞게 즐겨보세요.
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# 매콤한 낙지 콩나물 비빔밥
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]한남동의 파인다이닝 레스토랑인 "탑"의 헤드셰프 조용재 셰프가 개발한 낙지덮밥.사골육수로 맛을 낸 특제 양념과 날치알을 매칭하여, 낙지 볶음에 감칠 맛을 극대화 하였습니다.맛있게 매운 맛으로 입 맛을 자극하고 아삭한 콩나물과 다양한 야채와의 조화가 어우러지는 한끼입니다.CHEF'S TIP식었을 경우 별도로 제공된 용기에 담아 전자레인지에30초데워주세요.고명과 함께 비벼드세요.덮밥과 된장국을 곁들여 먹으면 더욱 맛있습니다.
# 음식 정보 성공
# =========================================
# 12000
# 음식 가격 성공
# =========================================
# 그라나파다노를 곁들인 닭다리살 김치볶음밥
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]이태원 복합문화공간 어그로빌리지(Uhgro Village)에 위치한 프렌치비스트로 바이휴고(By HUGO)의 원영호 헤드셰프가 셰플리를 위해 직접 개발한 시그니처 김치볶음밥매콤한 김치에 진한맛을 위한 두반장과 굴소스를 섞고 고소한 닭다리살을 푸짐하게 넣어 밥과 빠르게 볶은 다음, 반숙 계란 후라이와 그라나파다노 치즈를 얹고 황금팽이버섯과 쪽파, 트러플오일로 마무리하였습니다뻔한 맛의 김치볶음밥이 아닌 고급스러운 셰프의 요리를 만나보세요인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요비비지 마시고 모든 재료들을 함께 떠서 드세요
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 소불고기 궁중 비빔밥 '골동반'
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]불고기 양념으로 조리한 소고기를 메인으로 다양한 채소와 나물, 계란 등을 셰플리가 직접 배합한 고추장과 함께 비벼먹는 전통 궁중 비빔밥궁궐에서 먹는 비빔밥인 '골동반'을 셰플리 키친팀에서 재현한 음식으로, 우리에게 친숙한 불고기부터 맛깔나게 버무린 나물, 비빔밥 재료로는 생소한 부각까지 다양한 고명들을 하나하나 정성을 다해 조리하여 용기에 보기좋게 담고, 깔끔한 미역국까지 함께 준비합니다취향에 맞게 고추장을 넣은 다음 잘 비벼드시면 든든하면서도 건강한 한끼를 즐기실 수 있습니다인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다CHEF'S TIP식었을 경우 별도 제공해드린 용기에 담아 전자레인지에30초데워주세요따로 담아드린 고추장은 취향에 맞게 넣어드세요함께 드린 미역국은 비빔밥과 함께 드실 때 맛있습니다
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# 국내산 생등심 돈가츠 덮밥 '가츠동'
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]갓 튀긴 일본식 돈가츠에 달짝지근한 간장소스와 계란, 양파 등을 부어 구워낸 다음 밥 위에 얹어먹는 일본의 덮밥 요리얼리지 않은 국내산 돈육 생등심을 두툼하게 잘라 빵가루를 입혀 고온에서 바삭하게 튀겨낸 다음 그 위에 키친에서 직접 만든 일본식 간장소스를 넣어 섞은 계란과 양파 등을 부어 한 번 더 조리합니다넉넉한 양으로 드린 돈가츠를 소스와 계란으로 촉촉해진 밥과 함께 떠서 드셔보세요인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요비비지 마시고 모든 재료들을 함께 떠서 드세요함께 드린 단무지와 락교는 메인과 함께 드실 때 맛있습니다
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 된장국
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]2017 미슐랭 가이드 서울편에 등재된 모던한식 레스토랑 '민스키친(MIN'S KITCHEN)'의 김민지 오너셰프가 셰플리 고객들을 위해 특별히 준비한 한식 메뉴양념에 재워둔 대패삼겹살을 직화로 넉넉히 구워내 불맛을 살려 밥 위에 얹고, 셰프 특제 소스로 맛깔나게 무쳐낸 영양부추와 양파를 함께 곁들여 깔끔한 한국식 덮밥을 즐기실 수 있습니다함께 드린 된장국은 식었을 경우 별도 제공해드린 용기에 담아 전자레인지에 30초 데워드시면 더욱 맛있습니다.CHEF'S TIP비비지 마시고 고명과 밥을 함께 떠서 드세요전자레인지30초로 더욱 따뜻하게 드세요
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# /home/hanyonghee/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/ipykernel_launcher.py:165: DeprecationWarning: use driver.switch_to.alert instead
# 서울 강남구 역삼동 831-6 1층
# 주소 뽑기 성공
# =========================================
#
# 따뜻함, 건강함, 편리함을 추구하는 아시아 누들&라이스 레스토랑으로 아시아 각 지역의 특색 있는 요리를 선보입니다.
# 길거리와 먹거리라는 단어를 조합한 스트릿(strEAT)에서는 규동, 카라이멘, 오니기리 등 심플함과 정직함으로 만들어진 메뉴에
# 각국 아시아의 고유 문화와 맛을 담아냈으며, 푸드플라이를 통해 어디서나 간편하게 건강한 식사를 즐길 수 있습니다.
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀_국내산대만식 돼지 조림 덮밥(돼지고기_독일산)명란 아보카도 덮밥(돼지고기, 두부, 명란_국내산)대만식 마늘쫑 볶음 덮밥(돼지고기_국내산)해산물 날치알 볶음밥(오징어_중국산)삼겹 철판구이(돼지고기_독일산/갈치(양념젓갈),명란_국내산)야채 고로케(돼지고기_국내산)
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000]
# 최소 금액 성공
# =========================================
# 대만식 돼지 조림 덮밥
# 음식 메뉴 성공
# =========================================
# 오향, 팔각 등의 향이 진하게 우러나온 돼지고기 조림에 간장 맛을 들인 달걀과 볶은 청경채를 함께 곁들여 먹는 대만식 조림 덮밥
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 명란 아보카도 덮밥
# 음식 메뉴 성공
# =========================================
# 돼지고기로 만든 완자와 짭쪼름한 명란, 담백한 아보카도가 어우러진 덮밥
# 음식 정보 성공
# =========================================
# 8500
# 음식 가격 성공
# =========================================
# 대만식 마늘쫑 볶음 덮밥
# 음식 메뉴 성공
# =========================================
# 잘게 갈아낸 돼지고기와 마늘쫑을 스트릿만의 특제 소스에 매콤하게 볶아낸 대만식 볶음 덮밥
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 해산물 날치알 볶음밥
# 음식 메뉴 성공
# =========================================
# 탱글한 새우, 오징어, 날치알 등 신선한 해산물과 각종 채소를 뜨거운 철판 위에 볶아낸 철판 볶음밥
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 삼겹 철판구이
# 음식 메뉴 성공
# =========================================
# 철판에서 구워내 불맛이 살아있는 삼겹살에 명란, 와사비, 갈치 속젓의 삼합 소스까지 곁들여 더 맛있는 구이 메뉴*17시부터 주문 가능*
# 음식 정보 성공
# =========================================
# 21000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# 서울 강남구 역삼동 831-5 지상1층, 2층
# 주소 뽑기 성공
# =========================================
#
# 신선한 재료와 맛, 내 가족도 안심하고 먹을 수 있는 최고의 음식을 만들겠다는 확고한 일념 하나로 시작하였습니다.
# 1989년 10개 테이블과 간판도 없는 2층 가게에서 시작, 이제는 국내 뿐 아니라 중국과 일본에도 명소로 알려져 월 500명 정도의 외국인이
# 방문하는 명소가 되었으며 해외 신문, 잡지 등에서 맛집으로 소개되고 있을 만큼 전 세계의 다양한 미식가들의 폭 넓은 사람을 받고 있습니다.
#
# 이에 만족하지 않고 세계인의 입맛을 사로 잡을 수 있는 새로운 신메뉴 개발과 변하지 않는 맛과 신선한 재료 사용을 지켜갈 수 있도록 최선을 다하겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 족발, 쌀, 배추 : 국내산고춧가루 : 중국산보쌈 (돼지고기) : 독일산보쌈 김치속 (무, 배추) : 국내산보쌈김치속 (고추가루) : 중국산
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000, 30000]
# 최소 금액 성공
# =========================================
# A 세트 大
# 음식 메뉴 성공
# =========================================
# 족발 大 + 쟁반국수 + 펩시콜라 (500ml)
# 음식 정보 성공
# =========================================
# 48000
# 음식 가격 성공
# =========================================
# A 세트 中
# 음식 메뉴 성공
# =========================================
# 족발 中 + 쟁반국수 + 펩시콜라 (500ml)
# 음식 정보 성공
# =========================================
# 42000
# 음식 가격 성공
# =========================================
# B 세트 大
# 음식 메뉴 성공
# =========================================
# 족발+보쌈 大 + 쟁반국수 + 펩시콜라 (500ml)
# 음식 정보 성공
# =========================================
# 60000
# 음식 가격 성공
# =========================================
# B 세트 中
# 음식 메뉴 성공
# =========================================
# 족발+보쌈 中 + 쟁반국수 + 펩시콜라 (500ml)
# 음식 정보 성공
# =========================================
# 48000
# 음식 가격 성공
# =========================================
# C 세트 大
# 음식 메뉴 성공
# =========================================
# 반반족발 大 + 주먹밥 + 펩시콜라 (500ml)
# 음식 정보 성공
# =========================================
# 42000
# 음식 가격 성공
# =========================================
# C 세트 中
# 음식 메뉴 성공
# =========================================
# 반반족발 中 + 주먹밥 + 펩시콜라 (500ml)
# 음식 정보 성공
# =========================================
# 37000
# 음식 가격 성공
# =========================================
# 만족오향족발 (중, 2~3인분)
# 음식 메뉴 성공
# =========================================
# 콜라겐 가득~~한 껍질과 부드러운 살코기는 만족의 특제 마늘소스에 양배추채를 적셔 함께 먹으면 최고의 궁합!오향의 은은한 감칠맛의 만족오향족발!
# 음식 정보 성공
# =========================================
# 32000
# 음식 가격 성공
# =========================================
# 만족오향족발 (대, 3~4인분)
# 음식 메뉴 성공
# =========================================
# 콜라겐 가득~~한 껍질과 부드러운 살코기는 만족의 특제 마늘소스에 양배추채를 적셔 함께 먹으면 최고의 궁합!오향의 은은한 감칠맛의 만족오향족발!
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 만족오향족발 (특대, 4~5인분)
# 음식 메뉴 성공
# =========================================
# 콜라겐 가득~~한 껍질과 부드러운 살코기는 만족의 특제 마늘소스에 양배추채를 적셔 함께 먹으면 최고의 궁합!오향의 은은한 감칠맛의 만족오향족발!
# 음식 정보 성공
# =========================================
# 53000
# 음식 가격 성공
# =========================================
# 오향불족발 (2~3인분)
# 음식 메뉴 성공
# =========================================
# 화끈하게 매운 매력적인 불족발!천연조미료 청양고춧가루로 맛을 내 맛있게 매운 맛!
# 음식 정보 성공
# =========================================
# 34000
# 음식 가격 성공
# =========================================
# 냉채족발 (2~3인분)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 35000
# 음식 가격 성공
# =========================================
# 만족오향보쌈 (중, 2~3인분)
# 음식 메뉴 성공
# =========================================
# 오향의 은은한 향과 만족의 특제육수로 매일 직접 삶는 차세대 대표 메뉴, 만족오향보쌈!
# 음식 정보 성공
# =========================================
# 30000
# 음식 가격 성공
# =========================================
# 만족오향보쌈 (대, 3~4인분)
# 음식 메뉴 성공
# =========================================
# 향의 은은한 향과 만족의 특제육수로 매일 직접 삶는 차세대 대표 메뉴, 만족오향보쌈!
# 음식 정보 성공
# =========================================
# 35000
# 음식 가격 성공
# =========================================
# 족발 + 보쌈 (중, 2~3인분)
# 음식 메뉴 성공
# =========================================
# 만족의 터줏대감 족발과 차세대 대표메뉴 보쌈의 만남!
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 족발 + 보쌈 (대, 3~4인분)
# 음식 메뉴 성공
# =========================================
# 만족의 터줏대감 족발과 차세대 대표메뉴 보쌈의 만남
# 음식 정보 성공
# =========================================
# 51000
# 음식 가격 성공
# =========================================
# 불족 + 보쌈 (중, 2~3인분)
# 음식 메뉴 성공
# =========================================
# 맛있게 매운 불족과 보쌈의 만남
# 음식 정보 성공
# =========================================
# 34000
# 음식 가격 성공
# =========================================
# 불족 + 보쌈 (대, 3~4인분)
# 음식 메뉴 성공
# =========================================
# 맛있게 매운 불족과 보쌈의 만남
# 음식 정보 성공
# =========================================
# 39000
# 음식 가격 성공
# =========================================
# 족발 + 불족 (중, 2~3인분)
# 음식 메뉴 성공
# =========================================
# 만족오향족발과 불족발 모두 맛보고 싶을 때!두가지 맛을 한번에 느낄 수 있는 반반족발!
# 음식 정보 성공
# =========================================
# 34000
# 음식 가격 성공
# =========================================
# 족발 + 불족 (대, 3~4인분)
# 음식 메뉴 성공
# =========================================
# 만족오향족발과 불족발 모두 맛보고 싶을 때!두가지 맛을 한번에 느낄 수 있는 반반족발!
# 음식 정보 성공
# =========================================
# 39000
# 음식 가격 성공
# =========================================
# 쟁반국수
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 물만두 (22pcs)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 6000
# 음식 가격 성공
# =========================================
# 주먹밥 (self)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 콜라 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 사이다 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 추억의벤또
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# 서울 강남구 역삼동 792-6
# 주소 뽑기 성공
# =========================================
#
# 저희 업소는 불맛과 향을 내는 어떠한 보조재료를 넣지않고 요리합니다.
# 손님께서 주문하시면 그 즉시 오직 불의 강,약으로만 조리하기에 음식에서 풍기는 깊고 풍부한 불맛과 향기가 어우러져 더욱 맛있는 음식을 드실 수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀 국내산 / 삼겹살 칠레산 / 김치찜김치 국내산 / 김치찜고기 칠레산 / 고추가루 중국산 / 김치  중국산 / 소갈비살 미국산 / 쭈꾸미 중국산 / 제육 미국산 / 소왕갈비 미국산 / 뼈해장국 외국산 /
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000, 30000, 15000]
# 최소 금액 성공
# =========================================
# 직화소갈비살구이
# 음식 메뉴 성공
# =========================================
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리감치
# 음식 정보 성공
# =========================================
# 17000
# 음식 가격 성공
# =========================================
# 직화통삼겹살구이
# 음식 메뉴 성공
# =========================================
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식 정보 성공
# =========================================
# 15000
# 음식 가격 성공
# =========================================
# 직화대패삼겹살구이
# 음식 메뉴 성공
# =========================================
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식 정보 성공
# =========================================
# 15000
# 음식 가격 성공
# =========================================
# 직화매운삼겹살구이
# 음식 메뉴 성공
# =========================================
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식 정보 성공
# =========================================
# 16000
# 음식 가격 성공
# =========================================
# 직화제육볶음
# 음식 메뉴 성공
# =========================================
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 직화돼지갈비구이
# 음식 메뉴 성공
# =========================================
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식 정보 성공
# =========================================
# 15000
# 음식 가격 성공
# =========================================
# 소갈비살 + 냉면 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식 정보 성공
# =========================================
# 22000
# 음식 가격 성공
# =========================================
# 돼지갈비 + 냉면 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥 별도,겉절이,쌈야채 제공
# 음식 정보 성공
# =========================================
# 21000
# 음식 가격 성공
# =========================================
# 삼겹살 + 냉면 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식 정보 성공
# =========================================
# 18000
# 음식 가격 성공
# =========================================
# 대패삼겹살 + 냉면 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식 정보 성공
# =========================================
# 18000
# 음식 가격 성공
# =========================================
# 매운삼겹살 + 냉면 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식 정보 성공
# =========================================
# 18000
# 음식 가격 성공
# =========================================
# 제육볶음 + 냉면 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥 별도,겉절이,쌈야채 제공
# 음식 정보 성공
# =========================================
# 18000
# 음식 가격 성공
# =========================================
# 물냉면
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 비빔냉면
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 소갈비살 (450g)
# 음식 메뉴 성공
# =========================================
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식 정보 성공
# =========================================
# 42000
# 음식 가격 성공
# =========================================
# 통삼겹 (600g)
# 음식 메뉴 성공
# =========================================
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식 정보 성공
# =========================================
# 37000
# 음식 가격 성공
# =========================================
# 대패삼겹 (600g)
# 음식 메뉴 성공
# =========================================
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 매운삼겹 (600g)
# 음식 메뉴 성공
# =========================================
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식 정보 성공
# =========================================
# 41000
# 음식 가격 성공
# =========================================
# 제육볶음 (750g)
# 음식 메뉴 성공
# =========================================
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식 정보 성공
# =========================================
# 29000
# 음식 가격 성공
# =========================================
# 돼지갈비 (840g)
# 음식 메뉴 성공
# =========================================
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식 정보 성공
# =========================================
# 40000
# 음식 가격 성공
# =========================================
# 소왕갈비탕 (1인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식 정보 성공
# =========================================
# 12000
# 음식 가격 성공
# =========================================
# 육개장
# 음식 메뉴 성공
# =========================================
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 선지양평해장국
# 음식 메뉴 성공
# =========================================
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 뼈해장국 (1인)
# 음식 메뉴 성공
# =========================================
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 김치찜 (2인분)
# 음식 메뉴 성공
# =========================================
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 제육덮밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# SET A (4인분)
# 음식 메뉴 성공
# =========================================
# 직화소갈비살(2인) + 직화돼지갈비구이(2인) + 공깃밥 + 계란찜
# 음식 정보 성공
# =========================================
# 54000
# 음식 가격 성공
# =========================================
# SET B (4인분)
# 음식 메뉴 성공
# =========================================
# 직화소갈비살(2인) + 직화통삼겹살구이(2인) + 공깃밥 + 버섯토핑
# 음식 정보 성공
# =========================================
# 51000
# 음식 가격 성공
# =========================================
# 모듬세트 (6인분)
# 음식 메뉴 성공
# =========================================
# 직화소갈비살(2인) + 직화통삼겹살구이(2인) + 직화제육볶음(2인) + 공깃밥 + 계란찜
# 음식 정보 성공
# =========================================
# 70000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 계란찜
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 6000
# 음식 가격 성공
# =========================================
# 치즈계란찜
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 기본반찬(겉저리+파채)set
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 버섯추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 비엔나소세지추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 쌈추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 겉절이추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 사이다 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 콜라 (1.25L)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 4000
# 음식 가격 성공
# =========================================
# 사이다 (1.25L)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 4000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# 서울 강남구 역삼동 836 한스빌상가 1층
# 주소 뽑기 성공
# =========================================
#
# 49년 역사를 자랑하는 '연탄초벌구이점 십원집'니다.
# 반세기전부터 이어져 내려오는 십원집만의 비법,
# 한국인 전통의 푸근한 인정이 넘치는 십원집은 언제나 양심적인 가격으로 모시겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# *삼겹살;독일산산 *불고기;미국산  *족발;스페인산  *닭발;국내산+덴마크산  *막창;미국산  *곰창;국내산  *황태;러시아산  *오징어;국내산  *쭈꾸미;베트남산  *돼지갈비;미국산+스페인산 *미꾸라지;국내산  *쌀;국내산  *김치;중국산
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000, 30000, 15000, 20000]
# 최소 금액 성공
# =========================================
# 연탄불고기 도시락
# 음식 메뉴 성공
# =========================================
# 연탄불고기 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 연탄파불고기도시락
# 음식 메뉴 성공
# =========================================
# 연탄파불고기 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 연탄고추장불고기 도시락
# 음식 메뉴 성공
# =========================================
# 연탄고추장불고기 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 연탄삼겹살 도시락
# 음식 메뉴 성공
# =========================================
# 연탄삼겹살 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 연탄고추장삼겹살 도시락
# 음식 메뉴 성공
# =========================================
# 연탄고추장삼겹살 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# 연탄불고기 (400g, 2인분)set
# 음식 메뉴 성공
# =========================================
# 연탄불고기400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 23000
# 음식 가격 성공
# =========================================
# 연탄파불고기 (400g, 2인분)set
# 음식 메뉴 성공
# =========================================
# 연탄파불고기400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 25000
# 음식 가격 성공
# =========================================
# 연탄고추장불고기 (400g, 2인분)set
# 음식 메뉴 성공
# =========================================
# 연탄고추장불고기400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 27000
# 음식 가격 성공
# =========================================
# 연탄삼겹살 (400g,2인분)set
# 음식 메뉴 성공
# =========================================
# 400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 28000
# 음식 가격 성공
# =========================================
# 연탄고추장삼겹살 (400g, 2인분)set
# 음식 메뉴 성공
# =========================================
# 400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 30000
# 음식 가격 성공
# =========================================
# 연불쭈꾸미 (400g, 2인분) set
# 음식 메뉴 성공
# =========================================
# 연탄불고기(200g) + 쭈꾸미(200g) + 쌈야채(2인분) + 김치찌개 + 계란찜 + 공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 30000
# 음식 가격 성공
# =========================================
# 연탄매운족발 set
# 음식 메뉴 성공
# =========================================
# 연탄매운족발 (350g) + 셀프주먹밥 (1인분) + 계란찜
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 연탄매운닭발 set
# 음식 메뉴 성공
# =========================================
# 연탄매운닭발 (250g) + 셀프주먹밥 (1인분) + 계란찜
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 연탄 불곱창 set
# 음식 메뉴 성공
# =========================================
# 연탄 불곱창 (400g) + 셀프주먹밥 (1인분) + 계란찜
# 음식 정보 성공
# =========================================
# 24000
# 음식 가격 성공
# =========================================
# 연탄 불막창 set
# 음식 메뉴 성공
# =========================================
# 연탄 불막창 (400g) + 셀프주먹밥 (1인분) + 계란찜
# 음식 정보 성공
# =========================================
# 24000
# 음식 가격 성공
# =========================================
# 연불 물냉면
# 음식 메뉴 성공
# =========================================
# 연탄불고기(150g) + 물냉면
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 연불 비빔냉면
# 음식 메뉴 성공
# =========================================
# 연탄불고기(150g) + 비빔냉면
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 김치찌개만 (1인분)
# 음식 메뉴 성공
# =========================================
# 완조리공깃밥 별도기본반찬은 제공되지 않습니다.
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 부대찌개만 (1인분)
# 음식 메뉴 성공
# =========================================
# 완조리공깃밥 별도기본반찬은 제공되지 않습니다.
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 육개장만 (1인분)
# 음식 메뉴 성공
# =========================================
# 완조리공깃밥 별도기본반찬은 제공되지 않습니다.
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 추어탕만 (1인분)
# 음식 메뉴 성공
# =========================================
# 완조리공깃밥 별도기본반찬은 제공되지 않습니다.
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 계란찜
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 4000
# 음식 가격 성공
# =========================================
# 쌈야채 (상추,고추)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 콜라 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 사이다 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# 서울 강남구 역삼동 837-26 삼일프라자 1층
# 주소 뽑기 성공
# =========================================
#
# 한끼든든 퓨전 한식 수제직화도시락!!
# 직화락은 직화제육볶음과 직화오징어볶음을 메인으로 하는 직화볶음요리 전문점, 직화도시락 입니다.
# 직화도시락과 더불어 다양한 도시락을 즐겨보세요.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 오징어,쌀,계란,돈가스,떡갈비,닭고기 : 국내산돼지고기 : 미국산     김치 : 국내산,중국산고추가루: 중국산 국내산혼합양배추 .파. 양파: 국내산
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000, 30000, 15000, 20000, 16000]
# 최소 금액 성공
# =========================================
# 후덜덜 돼지
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식 정보 성공
# =========================================
# 6900
# 음식 가격 성공
# =========================================
# 두근두근 반반
# 음식 메뉴 성공
# =========================================
# 직화 제육볶음과 직화 오징어볶음을 모두 즐기고 싶은 분들께 강추! (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식 정보 성공
# =========================================
# 7400
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 스팸
# 음식 정보 성공
# =========================================
# 7100
# 음식 가격 성공
# =========================================
# 두근두근 (반반) + 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 직화 제육볶음과 직화 오징어볶음 + 스팸
# 음식 정보 성공
# =========================================
# 7500
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 새우 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 새우
# 음식 정보 성공
# =========================================
# 7100
# 음식 가격 성공
# =========================================
# 두근두근 (반반) + 새우 도시락
# 음식 메뉴 성공
# =========================================
# 직화 제육볶음과 직화 오징어볶음 + 새우
# 음식 정보 성공
# =========================================
# 7500
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 소세지 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 소세지
# 음식 정보 성공
# =========================================
# 7300
# 음식 가격 성공
# =========================================
# 두근두근 (반반) + 소세지 도시락
# 음식 메뉴 성공
# =========================================
# 직화 제육볶음과 직화 오징어볶음 + 소세지
# 음식 정보 성공
# =========================================
# 7700
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 생선가스 도시락
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 7800
# 음식 가격 성공
# =========================================
# 두근두근 (반반) + 생선가스 도시락
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 8200
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 떡갈비 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 떡갈비
# 음식 정보 성공
# =========================================
# 8300
# 음식 가격 성공
# =========================================
# 두근두근 (반반) + 떡갈비 도시락
# 음식 메뉴 성공
# =========================================
# 직화 제육볶음과 직화 오징어볶음 + 떡갈비
# 음식 정보 성공
# =========================================
# 8700
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 돈가스
# 음식 정보 성공
# =========================================
# 8800
# 음식 가격 성공
# =========================================
# 두근두근 (반반) + 돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 직화 제육볶음과 직화 오징어볶음 + 돈가스
# 음식 정보 성공
# =========================================
# 9200
# 음식 가격 성공
# =========================================
# 후덜덜 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 직화제육볶음만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 부르부르 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 직화오징어볶음만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 반반 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 반반볶음(직화제육볶음,직화오징어볶음)만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 11900
# 음식 가격 성공
# =========================================
# 한끼라도 후덜덜
# 음식 메뉴 성공
# =========================================
# 후덜덜 돼지 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 15900
# 음식 가격 성공
# =========================================
# 한끼라도 부르부르
# 음식 메뉴 성공
# =========================================
# 부르부르 오징어 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 15900
# 음식 가격 성공
# =========================================
# 한끼라도 반반
# 음식 메뉴 성공
# =========================================
# 두근두근 반반 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 16400
# 음식 가격 성공
# =========================================
# 김치찌개 추가
# 음식 메뉴 성공
# =========================================
# 공깃밥 미포함
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 뜨끈한 소고기 미역국 추가
# 음식 메뉴 성공
# =========================================
# 공깃밥 미포함
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 공기밥 추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 볶음김치 추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 800
# 음식 가격 성공
# =========================================
# 매콤닭강정 도시락
# 음식 메뉴 성공
# =========================================
# 매콤한 닭강정 도시락
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 담백한 스팸 도시락
# 음식 정보 성공
# =========================================
# 5500
# 음식 가격 성공
# =========================================
# 치킨 도시락
# 음식 메뉴 성공
# =========================================
# 치킨도시락
# 음식 정보 성공
# =========================================
# 6500
# 음식 가격 성공
# =========================================
# 탕수육 도시락
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 6500
# 음식 가격 성공
# =========================================
# 추억의 도시락
# 음식 메뉴 성공
# =========================================
# 볶음김치 + 계란 + 밥
# 음식 정보 성공
# =========================================
# 4300
# 음식 가격 성공
# =========================================
# 칠리새우 도시락
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 7700
# 음식 가격 성공
# =========================================
# 아사삭 돈가스
# 음식 메뉴 성공
# =========================================
# 국내산 돼지고기 등심으로 주문즉시 바삭하게 튀겨낸 돈가스와 해쉬브라운
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 더블돈가스
# 음식 메뉴 성공
# =========================================
# 돈가스가 두배
# 음식 정보 성공
# =========================================
# 8200
# 음식 가격 성공
# =========================================
# 돈가스 새우
# 음식 메뉴 성공
# =========================================
# 돈가스와 왕새우튀김을 한번에 즐길 수 있는 메뉴입니다.
# 음식 정보 성공
# =========================================
# 7200
# 음식 가격 성공
# =========================================
# 수제돈갈비
# 음식 메뉴 성공
# =========================================
# 떡갈비와 돈가스를 한번에 즐길 수 있는 메뉴입니다.
# 음식 정보 성공
# =========================================
# 7800
# 음식 가격 성공
# =========================================
# 옛날떡갈비 도시락
# 음식 메뉴 성공
# =========================================
# 담백한 떡갈비와 추억의 도시락
# 음식 정보 성공
# =========================================
# 6200
# 음식 가격 성공
# =========================================
# 떡갈비닭강정 도시락
# 음식 메뉴 성공
# =========================================
# 떡갈비와 매콤닭강정
# 음식 정보 성공
# =========================================
# 8200
# 음식 가격 성공
# =========================================
# 생선가스 도시락
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 생선가스새우 도시락
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 6100
# 음식 가격 성공
# =========================================
# 카레돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 돈가스
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 카레새우 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 왕새우튀김(2pcs)
# 음식 정보 성공
# =========================================
# 6600
# 음식 가격 성공
# =========================================
# 카레떡갈비 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 떡갈비
# 음식 정보 성공
# =========================================
# 6500
# 음식 가격 성공
# =========================================
# 카레소세지 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 소세지
# 음식 정보 성공
# =========================================
# 5500
# 음식 가격 성공
# =========================================
# 카레옛날도시락
# 음식 메뉴 성공
# =========================================
# 카레와 추억의 도시락
# 음식 정보 성공
# =========================================
# 5200
# 음식 가격 성공
# =========================================
# 카레스팸 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 스팸2장
# 음식 정보 성공
# =========================================
# 6600
# 음식 가격 성공
# =========================================
# 치즈스틱(4ea)
# 음식 메뉴 성공
# =========================================
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 김말이(6ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 군만두(6ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 치킨 1box
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 7900
# 음식 가격 성공
# =========================================
# 케이준감자튀김 (300g)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 4000
# 음식 가격 성공
# =========================================
# 매콤닭강정 1box
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 8900
# 음식 가격 성공
# =========================================
# 치킨반반 1Box (400g)
# 음식 메뉴 성공
# =========================================
# (매콤닭강정 + 치킨)
# 음식 정보 성공
# =========================================
# 8900
# 음식 가격 성공
# =========================================
# 왕새우 1Box (8ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 9900
# 음식 가격 성공
# =========================================
# 후덜덜직화1인 정식세트
# 음식 메뉴 성공
# =========================================
# 후덜덜돼지직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식 정보 성공
# =========================================
# 17000
# 음식 가격 성공
# =========================================
# 두근두근반반직화1인 정식세트
# 음식 메뉴 성공
# =========================================
# 두근두근반반직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식 정보 성공
# =========================================
# 17500
# 음식 가격 성공
# =========================================
# 후덜덜직화 2인 정식세트
# 음식 메뉴 성공
# =========================================
# 후덜덜돼지직화1Box + 추억의도시락2개 + 리코타발사믹샐러드 + 오늘의반찬3종 + 김치찌개
# 음식 정보 성공
# =========================================
# 29000
# 음식 가격 성공
# =========================================
# 두근두근반반직화2인 정식세트
# 음식 메뉴 성공
# =========================================
# 두근두근반반직화1Box + 추억의도시락2개 + 리코타발사믹샐러드 + 오늘의반찬3종 + 김치찌개
# 음식 정보 성공
# =========================================
# 29500
# 음식 가격 성공
# =========================================
# 콜라(355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 사이다(355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 환타 오렌지 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 웰치스 포도 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# 서울 강남구 역삼동 817-26 1,2층
# 주소 뽑기 성공
# =========================================
#
#
#
# 식신로드, 생생정보, 생방송오늘저녁 등 각종 방송 및 입에서 입으로 이미 검증된 강남 맛집, 이제 백억하누의 음식을 푸드플라이를 통해 집에서 편하게 접하실 수 있습니다.
# 항상 고객이 만족하실수 있는 음식 및 서비스로 고객님을 모시겠습니다.
# 백억하누 강남 본점 많이 이용해주세요^^
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# *쌀 : 국내산*소고기 : 국내산 한우*갈비탕 : 미국산*전복 : 국내산*김치 : 국내산*누룽지 : 국내산*김치찌개 배추김치 : 중국산*돼지고기 : 목전지 미국산, 삼겹 독일산
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000, 30000, 15000, 20000, 16000, 15000]
# 최소 금액 성공
# =========================================
# 1++한우차돌박이 (2인분)
# 음식 메뉴 성공
# =========================================
# 기본반찬 5종 + 추가반찬 3종 서비스식사 및 안주로 최고! 정육점에서도 찾기 힘든 우리나라 최고급 차돌박이를 집에서 즐기실 수 있습니다.
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 백억한우불고기 (2인분, 조리)
# 음식 메뉴 성공
# =========================================
# 국내산 한우 최고등급 1++ (400g)  + 기본반찬 + 추가반찬 3종 + 공깃밥 2개 제공각종 언론에서 극찬한 서울식 한우 불고기
# 음식 정보 성공
# =========================================
# 44000
# 음식 가격 성공
# =========================================
# 백억 특정식
# 음식 메뉴 성공
# =========================================
# 한우불고기 + 한우된장찌개 + 고등어구이 (2인기준 1마리) + 추가반찬 3종
# 음식 정보 성공
# =========================================
# 17500
# 음식 가격 성공
# =========================================
# 한우 육회 비빔밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 한우불고기 + 한우된장찌개
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 11500
# 음식 가격 성공
# =========================================
# 묵은지 김치찌개
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 8500
# 음식 가격 성공
# =========================================
# 한우 불고기 덮밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 8500
# 음식 가격 성공
# =========================================
# 한우 소고기 국밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 8500
# 음식 가격 성공
# =========================================
# 누룽지탕 정식
# 음식 메뉴 성공
# =========================================
# 누룽지탕 + 한우된장찌개
# 음식 정보 성공
# =========================================
# 9900
# 음식 가격 성공
# =========================================
# 백억 영양 전복갈비탕
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 백억 영양 특갈비탕
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# ...
# 10000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 통돼지 김치찌개 (안주)
# 음식 메뉴 성공
# =========================================
# 대(2~3인분), 왕대(4인분)공깃밥 제외,포장비 2000원 포함 가격입니다.구수한 묵은지와 통돼지고기, 두부가 가득~ 얼큰하고 시원한 김치찌개입니다
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 꽁치 김치찌개 (안주)
# 음식 메뉴 성공
# =========================================
# 2인분공깃밥 제외,포장비 2000원 포함 가격입니다.꽁치를 넣고 보글보글 끊인, 시원하고 깊은맛의 김치찌개입니다
# 음식 정보 성공
# =========================================
# 19000
# 음식 가격 성공
# =========================================
# 참치 김치찌개 (안주)
# 음식 메뉴 성공
# =========================================
# 2인분공깃밥 제외,포장비 2000원 포함 가격입니다.묵은지와 참치를 넣고 끓인 시원하고 담백한 김치찌개입니다
# 음식 정보 성공
# =========================================
# 19000
# 음식 가격 성공
# =========================================
# 동그랑땡 (3pcs, 안주)
# 음식 메뉴 성공
# =========================================
# 공깃밥 제외
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 계란말이 (안주)
# 음식 메뉴 성공
# =========================================
# 공깃밥 제외
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 콜라 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 사이다 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 환타 오렌지 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# //*[@id="restaurants"]/div/a[37] 번 오류
# 서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46서울서울 강남구 역삼동 827-46
# 주소 뽑기 성공
# =========================================
#
# 고기듬뿍 통돼지김치찌개부터 고등어, 삼치구이까지 국가대표 한식메뉴만 모았습니다.
# 든든한 한끼식사! 통돼지 찌개집이 24시간 책임집니다!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 가게 원산지 뽑기 성공
# =========================================
# 쌀,배추김치,돼지고기(찌개),삼겹살,돼지갈비,동그랑땡,삼치,꽁치 : 국내산
# 가게 원산지 뽑기 성공
# =========================================
# 김치(찌개),두부,콩나물 : 국내산,중국산
# 가게 원산지 뽑기 성공
# =========================================
# 떡갈비 : 국내산,칠레산
# 가게 원산지 뽑기 성공
# =========================================
# 고등어 : 노르웨이산
# 가게 원산지 뽑기 성공
# =========================================
# 굴비,콩,고춧가루 : 중국산
# 가게 원산지 뽑기 성공
# =========================================
#
# 가게 원산지 뽑기 성공
# =========================================
# [8000, 15000, 30000, 15000, 20000, 16000, 15000, 22000, 12000, 16000, 7000, 16000, 14000, 20000, 15000, 37000, 15000, 19000, 8000, 31000, 30000, 29000, 20000, 16000, 20000, 20000, 30000, 20000, 15000, 25000, 10000, 10000, 10000, 10000, 10000, 10000, 10000]
# 최소 금액 성공
# =========================================
# 갈치구이 ( 식사)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 모듬생선구이 (식사)
# 음식 메뉴 성공
# =========================================
# 공깃밥 기본제공2인분갈치, 임연수, 조기, 꽁치외 생선으로 구성된 메뉴로 계절과 시장 사입에 따라 메뉴 구성에 변동이 있을 수 있습니다.
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 생고기 김치찌개 (식사)
# 음식 메뉴 성공
# =========================================
# 공깃밥 기본제공,포장비 1000원 포함 가격입니다.개별포장 요청시엔 고객요청사항에 기재 꼭 부탁드립니다.생고기를 넣어 더욱 맛있는 시원하고 담백한 김치찌개입니다
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 고등어구이 (식사)
# 음식 메뉴 성공
# =========================================
# 공깃밥 기본제공,포장비 1000원 포함 가격입니다.겉은 바삭바삭 속은 촉촉~ 잘 구워진 고등어구입니다
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 삼치구이 (식사)
# 음식 메뉴 성공
# =========================================
# 공깃밥 기본제공,포장비 1000원 포함 가격입니다.생선중에 단백질이 가장 많다는 삼치를 구웠습니다
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 동그랑땡 (3pcs, 식사)
# 음식 메뉴 성공
# =========================================
# 공깃밥 기본제공,포장비 1000원 포함 가격입니다.직접 재료를 다져 만든 수제 동그랑땡
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 계란말이 (식사)
# 음식 메뉴 성공
# =========================================
# 공깃밥 기본제공김치찌개의 매운맛을 중화시켜주는 두툼하고 담백한 계란말이입니다
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 통돼지 김치찌개 (안주)
# 음식 메뉴 성공
# =========================================
# 대(2~3인분), 왕대(4인분)공깃밥 제외,포장비 2000원 포함 가격입니다.구수한 묵은지와 통돼지고기, 두부가 가득~ 얼큰하고 시원한 김치찌개입니다
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 꽁치 김치찌개 (안주)
# 음식 메뉴 성공
# =========================================
# 2인분공깃밥 제외,포장비 2000원 포함 가격입니다.꽁치를 넣고 보글보글 끊인, 시원하고 깊은맛의 김치찌개입니다
# 음식 정보 성공
# =========================================
# 19000
# 음식 가격 성공
# =========================================
# 참치 김치찌개 (안주)
# 음식 메뉴 성공
# =========================================
# 2인분공깃밥 제외,포장비 2000원 포함 가격입니다.묵은지와 참치를 넣고 끓인 시원하고 담백한 김치찌개입니다
# 음식 정보 성공
# =========================================
# 19000
# 음식 가격 성공
# =========================================
# 동그랑땡 (3pcs, 안주)
# 음식 메뉴 성공
# =========================================
# 공깃밥 제외
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 계란말이 (안주)
# 음식 메뉴 성공
# =========================================
# 공깃밥 제외
# 음식 정보 성공
# =========================================
# 10000
# 음식 가격 성공
# =========================================
# 콜라 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 사이다 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 환타 오렌지 (355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ================== 가게 하나 끝 ==================
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f3e2204df60>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-65-d7c5d57517a7> in <module>
#     169         pass
#     170
# --> 171     driver.back()
#     172     driver.implicitly_wait(8)
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in back(self)
#     811             driver.back()
#     812         """
# --> 813         self.execute(Command.GO_BACK)
#     814
#     815     def forward(self):
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     320             response = conn.urlopen(method, url, **kw)
#     321         else:
# --> 322             response = conn.urlopen(method, u.request_uri, **kw)
#     323
#     324         redirect_location = redirect and response.get_redirect_location()
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# ~/.pyenv/versions/3.6.6/envs/fc-webtoon/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     396
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#     400         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=42485): Max retries exceeded with url: /session/a176a2889cc33d81605c2ab39f0cbd83/back (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3e2204df60>: Failed to establish a new connection: [Errno 111] Connection refused',))

# %%
driver = webdriver.Chrome('/usr/sbin/chromedriver')
driver.implicitly_wait(3)

driver.get('https://www.foodfly.co.kr/restaurants/show/13449')
# alert = driver.switch_to_alert()
# alert.accept()

html2 = driver.page_source
soup = BeautifulSoup(html2, 'lxml')

store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
origin_content = store_origin.select('p')
for w in origin_content:
    store_origin_info = w.get_text(strip=True)
    print(store_origin_info)
# Out:
# 족발(생족),쌀,쌈야채(유기농) : 국내산새우 : 국내산,말레이시아산,태국산

# %%
content = store_origin.select('span')

# %%
for i in content:
    print(i.get_text())
# Out:
# [메인메뉴_완조리]
# [메인메뉴_완조리]
#
# 특제간장으로 맛을 살린
# 여수 새꼬막비빔밥 :
# 새꼬막(국내산), 채소류(국내산, 중국산), 고춧가루(국내산)
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리 : 새우(베트남산), 채소류(국내산, 중국산), 레드커리페이스트(태국산), 휘핑크림(국내산)
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리 :
# 새우(베트남산), 채소류(국내산, 중국산), 레드커리페이스트(태국산), 휘핑크림(국내산)
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또 : 닭다리살(브라질산), 치킨파우더(대만산), 잡곡(국내산), 고르곤졸라(이탈리아산)
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또 : 닭다리살(브라질산), 치킨파우더(대만산), 잡곡(국내산), 고르곤졸라(이탈리아산)
# 매콤한 낙지 콩나물비빔밥 : 쌀(국내산), 낙지(중국산), 채소류(국내산)
# 매콤한 낙지 콩나물비빔밥 : 쌀(국내산), 낙지(중국산), 채소류(국내산)
# 그라나파다노를 곁들인 닭다리살 김치볶음밥 :
# 그라나파다노를 곁들인 닭다리살 김치볶음밥 :
# 김치(국내산), 쌀(국내산), 계란(국내산), 채소류(국내산), 정육(브라질산), 그라나파다노(이탈리아산), 트러플오일(이탈리아산), 굴소스(홍콩산), 두반장(중국산)
# 소불고기 궁중 비빔밥 '골동반' :
#  소고기(호주산), 계란(국내산), 시금치(국내산), 튀각(국내산), 쌀(국내산), 미역(국내산), 고사리(중국산), 당근(중국산), 청포묵(중국산), 숙주(중국산), 은행(중국산)
# 국내산 생등심 돈가츠 덮밥 '가츠동' :
# 돼지등심(국내산), 계란(국내산), 쌀(국내산), 채소류(국내산), 간장(일본산), 단무지(중국산), 락교(중국산)
# 아보카도를 곁들인 연어회덮밥 :
# 아보카도를 곁들인 연어회덮밥 :
# 아보카도를 곁들인 연어회덮밥 :
# 연어(노르웨이산), 아보카도(미국산), 채소류(국내산), 쌀(국내산), 계란(국내산), 날치알(인도네시아산)
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 콩나물북엇국 :
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 콩나물북엇국
#  :
#  :
# 삼겹살(네덜란드),
# 쌀(국내산), 채소류(국내산), 고추가루(국내산)
#
# [사이드메뉴_완조리]
# [사이드메뉴_완조리]
#
# 종가집 맛김치 50g :
# 배추(국산), 고춧가루(국산), 김치양념(국산)
# 반숙계란 니스와즈 샐러드 :
# 그린빈(중국산), 감자(국내산), 블랙올리브(스페인산), 계란(국내산), 참치(우너양산), 로메인(국내산), 방울토마토(국내산)
# 아삭아삭한 레몬 진저 피클 :
# 채소류(국내산),
# 레몬(미국산),
# 레몬그라스(태국산)
# 피나콜라다 코코넛 시럽을 곁들인 상큼한 파인애플
#  : 파인애플
# (필리핀), 연유(국내산), 리큐르
# (미국산)
# 오렌지 필로 풍미를 더한 수제 티라미수 :
# 다크커버춰(프랑스산),
# 마스카포네(이탈리아산),
# 사보이아르디(이탈리아산),
# 계란(국내산),
# 생크림(국내산),
# 오렌지(미국산),
# 리큐르(네덜란드산)
# 고소한 명란마요 밥 :
# 쌀 (국내산), 명란 (러시아산)
# 명란마요소스 치킨 가라아게 (5조각) :
# 정육(태국산), 명란(러시아산)
# 트러플향 감자튀김 :
# 트러플향 감자튀김 :
# 트러플향 감자튀김 :
# 감자튀김(미국산),
# 트러플오일(이탈리아산)
# 뉴욕식 버팔로윙 (5조각) :
# 뉴욕식 버팔로윙 (5조각) :
# 뉴욕식 버팔로윙 (5조각) :
# 치킨윙(태국산)
